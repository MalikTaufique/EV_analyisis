# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Data=pd.read_csv('/content/station_data_dataverse.csv')

# %%
Data.head(3)
# Out:
#    sessionId  kwhTotal  dollars              created                ended  \
# 0    1366563      7.78     0.00  0014-11-18 15:40:26  0014-11-18 17:11:04
# 1    3075723      9.74     0.00  0014-11-19 17:40:26  0014-11-19 19:51:04
# 2    4228788      6.76     0.58  0014-11-21 12:05:46  0014-11-21 16:46:04
#
#    startTime  endTime  chargeTimeHrs weekday platform  ...  managerVehicle  \
# 0         15       17       1.510556     Tue  android  ...               0
# 1         17       19       2.177222     Wed  android  ...               0
# 2         12       16       4.671667     Fri  android  ...               0
#
#    facilityType  Mon  Tues  Wed  Thurs  Fri  Sat  Sun  reportedZip
# 0             3    0     1    0      0    0    0    0            0
# 1             3    0     0    1      0    0    0    0            0
# 2             3    0     0    0      0    1    0    0            0
#
# [3 rows x 24 columns]

# %%
Data.sample(3)
# Out:
#       sessionId  kwhTotal  dollars              created                ended  \
# 26      6178541     20.95      0.0  0015-02-19 18:09:36  0015-02-19 21:49:06
# 1743    1502872      4.92      0.0  0015-04-15 13:12:49  0015-04-15 16:49:05
# 326     2977982      6.55      0.0  0015-01-15 13:51:10  0015-01-15 16:09:04
#
#       startTime  endTime  chargeTimeHrs weekday platform  ...  managerVehicle  \
# 26           18       21       3.658333     Thu  android  ...               0
# 1743         13       16       3.604444     Wed      ios  ...               0
# 326          13       16       2.298333     Thu  android  ...               0
#
#       facilityType  Mon  Tues  Wed  Thurs  Fri  Sat  Sun  reportedZip
# 26               3    0     0    0      1    0    0    0            0
# 1743             1    0     0    1      0    0    0    0            1
# 326              3    0     0    0      1    0    0    0            0
#
# [3 rows x 24 columns]

# %%
Data.tail(5)
# Out:
#       sessionId  kwhTotal  dollars              created                ended  \
# 3390    7021565      6.74      0.0  0015-10-01 16:31:18  0015-10-01 19:59:08
# 3391    3758092      6.86      0.0  0015-10-02 16:28:48  0015-10-02 19:27:05
# 3392    5858374      6.07      0.0  0015-09-30 16:54:22  0015-09-30 20:24:06
# 3393    2586645      5.74      0.0  0015-09-24 11:43:02  0015-09-24 13:55:12
# 3394    7860608      6.95      0.0  0015-10-01 16:43:05  0015-10-01 19:42:06
#
#       startTime  endTime  chargeTimeHrs weekday platform  ...  managerVehicle  \
# 3390         16       19       3.463889     Thu      ios  ...               0
# 3391         16       19       2.971389     Fri      ios  ...               0
# 3392         16       20       3.495556     Wed  android  ...               0
# 3393         11       13       2.202778     Thu      ios  ...               1
# 3394         16       19       2.983611     Thu      ios  ...               0
#
# ...

# %%
Data.columns
# Out:
# Index(['sessionId', 'kwhTotal', 'dollars', 'created', 'ended', 'startTime',
#        'endTime', 'chargeTimeHrs', 'weekday', 'platform', 'distance', 'userId',
#        'stationId', 'locationId', 'managerVehicle', 'facilityType', 'Mon',
#        'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'reportedZip'],
#       dtype='object')

# %%
Data.isnull().sum()
# Out:
# sessionId            0
# kwhTotal             0
# dollars              0
# created              0
# ended                0
# startTime            0
# endTime              0
# chargeTimeHrs        0
# weekday              0
# platform             0
# distance          1065
# userId               0
# stationId            0
# locationId           0
# managerVehicle       0
# facilityType         0
# Mon                  0
# Tues                 0
# Wed                  0
# Thurs                0
# Fri                  0
# Sat                  0
# Sun                  0
# reportedZip          0
# dtype: int64

# %%
Data.fillna(0,inplace=True)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3395 entries, 0 to 3394
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sessionId       3395 non-null   int64
#  1   kwhTotal        3395 non-null   float64
#  2   dollars         3395 non-null   float64
#  3   created         3395 non-null   object
#  4   ended           3395 non-null   object
#  5   startTime       3395 non-null   int64
#  6   endTime         3395 non-null   int64
#  7   chargeTimeHrs   3395 non-null   float64
#  8   weekday         3395 non-null   object
#  9   platform        3395 non-null   object
#  10  distance        3395 non-null   float64
#  11  userId          3395 non-null   int64
#  12  stationId       3395 non-null   int64
#  13  locationId      3395 non-null   int64
#  14  managerVehicle  3395 non-null   int64
#  15  facilityType    3395 non-null   int64
#  16  Mon             3395 non-null   int64
# ...

# %%
# Example handling missing values

# %%
Data.fillna({
    'kwhTotal':Data['kwhTotal'].median(),
    'platform':Data['platform'].mode()[0],
}, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x=Data["kwhTotal"])
plt.title("Outlier Detection for kWh Consumed")
plt.show()

# %%
# Remove outliers using the IQR method
Q1 = Data["kwhTotal"].quantile(0.25)
Q3 = Data["kwhTotal"].quantile(0.75)
IQR = Q3 - Q1

# Define acceptable range
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter data
Data = Data[(Data["kwhTotal"] >= lower_bound) & (Data["kwhTotal"] <= upper_bound)]

# %%
Data =pd.get_dummies(Data,columns=["platform","weekday"],drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
cols_to_scale =["kwhTotal", "chargeTimeHrs", "distance"]

# apply MinMax scaling
Data[cols_to_scale] = scaler.fit_transform(Data[cols_to_scale])

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3134 entries, 0 to 3394
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sessionId       3134 non-null   int64
#  1   kwhTotal        3134 non-null   float64
#  2   dollars         3134 non-null   float64
#  3   created         3134 non-null   object
#  4   ended           3134 non-null   object
#  5   startTime       3134 non-null   int64
#  6   endTime         3134 non-null   int64
#  7   chargeTimeHrs   3134 non-null   float64
#  8   distance        3134 non-null   float64
#  9   userId          3134 non-null   int64
#  10  stationId       3134 non-null   int64
#  11  locationId      3134 non-null   int64
#  12  managerVehicle  3134 non-null   int64
#  13  facilityType    3134 non-null   int64
#  14  Mon             3134 non-null   int64
#  15  Tues            3134 non-null   int64
#  16  Wed             3134 non-null   int64
# ...

# %%
Data.head()
# Out:
#    sessionId  kwhTotal  dollars              created                ended  \
# 0    1366563  1.283671     0.00  0014-11-18 15:40:26  0014-11-18 17:11:04
# 1    3075723  2.408536     0.00  0014-11-19 17:40:26  0014-11-19 19:51:04
# 2    4228788  0.698283     0.58  0014-11-21 12:05:46  0014-11-21 16:46:04
# 3    3173284  0.359676     0.00  0014-12-03 19:16:12  0014-12-03 21:02:18
# 4    3266500 -2.647615     0.00  0014-12-11 20:56:11  0014-12-11 21:14:06
#
#    startTime  endTime  chargeTimeHrs  distance    userId  ...  Sun  \
# 0         15       17      -0.923453 -1.040727  35897499  ...    0
# 1         17       19      -0.474562 -1.040727  35897499  ...    0
# 2         12       16       1.205037 -1.040727  35897499  ...    0
# 3         19       21      -0.749881 -1.040727  35897499  ...    0
# 4         20       21      -1.739498 -1.040727  35897499  ...    0
#
#    reportedZip  platform_ios  platform_web  weekday_Mon  weekday_Sat  \
# ...

# %%
Data.describe()
# Out:
#           sessionId      kwhTotal      dollars    startTime      endTime  \
# count  3.134000e+03  3.134000e+03  3134.000000  3134.000000  3134.000000
# mean   5.468787e+06 -2.902025e-16     0.119180    13.697830    16.499043
# std    2.589332e+06  1.000160e+00     0.495348     3.115955     3.245537
# min    1.004821e+06 -2.819788e+00     0.000000     0.000000     0.000000
# 25%    3.219640e+06 -6.102330e-01     0.000000    11.000000    14.000000
# 50%    5.399612e+06  3.740233e-01     0.000000    13.000000    16.000000
# 75%    7.720150e+06  7.212391e-01     0.000000    16.750000    20.000000
# max    9.998981e+06  2.867664e+00     7.500000    23.000000    23.000000
#
#        chargeTimeHrs      distance        userId      stationId  \
# count   3.134000e+03  3.134000e+03  3.134000e+03    3134.000000
# mean    8.672068e-17  9.975712e-17  5.665175e+07  575817.642948
# std     1.000160e+00  1.000160e+00  2.662830e+07  257413.097733
# ...

# %%
print(Data["platform_ios"].unique())
# Out:
# [False  True]

# %%
print(Data["weekday_Mon"].unique)
# Out:
# <bound method Series.unique of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3390    False
# 3391    False
# 3392    False
# 3393    False
# 3394    False
# Name: weekday_Mon, Length: 3134, dtype: bool>

# %%
# Distribution of Energy Consumption (kWh)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.histplot(Data["kwhTotal"], bins=30, kde=True, color="blue")
plt.title("Distribution of Energy Consumption (kWh)")
plt.xlabel("kWh Consumed")
plt.ylabel("Frequency")
plt.show()

# %%
#Charging Sessions by Hour of the Day

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=Data["chargeTimeHrs"], y=Data["kwhTotal"], alpha=0.6)
plt.title("Charging Duration vs Energy Consumption")
plt.xlabel("Charging Duration (Hours)")
plt.ylabel("kWh Consumed")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=Data["locationId"], order=Data["locationId"].value_counts().index[:10], palette="magma")
plt.title("Top 10 Charging Locations by Demand")
plt.xlabel("Location ID")
plt.ylabel("Number of Charging Sessions")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-29-f6f52c3a7ae5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=Data["locationId"], order=Data["locationId"].value_counts().index[:10], palette="magma")

# %%
# Select only numeric columns for correlation
numeric_df = Data.select_dtypes(include=["number"])

# Generate heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=Data["kwhTotal"], color="red")
plt.title("Box Plot of Energy Consumption (kWh)")
plt.ylabel("kWh Consumed")
plt.show()

# %%
Data.to_csv("/content/cleaned_station_data_dataverse.csv")

# %%
Data.to_csv
